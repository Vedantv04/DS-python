# %%
 import pandas as pd
 df=pd.read_csv('Salaries.csv')

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df['discipline'].value_counts().plot.bar()

# %%
ages=[30,30,45,29,50,47]
salary=[30000,38000,40000,29000,60000,50000]
plt.xlabel("Age of person")
plt.ylabel("Salary of person")
plt.title("Salary Distribution of employees")
plt.scatter(ages,salary,color="red")

# %%
from math import *
plt.figure(figsize=(16,9))
x=list(range(-10,11))
y=[i**2 for i in x]
plt.subplot(3,4,1)
plt.plot(x,y)

y=[i**3 for i in x]
plt.subplot(3,4,12)
plt.plot(x,y)

y=[sin(i) for i in x]
plt.subplot(3,4,7)
plt.plot(x,y)

y=[tan(i) for i in x]
plt.subplot(3,4,3)
plt.plot(x,y)

# %%
import pandas as pd
data=pd.read_csv("mtcars.csv")
data

# %%
pd.crosstab(data['cyl'],data['gear'])
# Out:
# gear   3  4  5
# cyl
# 4      1  8  2
# 6      2  4  1
# 8     12  0  2

# %%
pd.crosstab(data['cyl'],data['gear']).plot(kind='bar')
# Out:
# <Axes: xlabel='cyl'>

# %%
data["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
data.gear.value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='gear'>

# %%
plt.scatter(data.mpg,data.qsec,color="green")

# %%
plt.hist(data.mpg,color="black",edgecolor="red",bins=15)
# Out:
# (array([2., 1., 3., 5., 3., 4., 2., 5., 1., 1., 1., 0., 2., 0., 2.]),
#  array([10.4       , 11.96666667, 13.53333333, 15.1       , 16.66666667,
#         18.23333333, 19.8       , 21.36666667, 22.93333333, 24.5       ,
#         26.06666667, 27.63333333, 29.2       , 30.76666667, 32.33333333,
#         33.9       ]),
#  <BarContainer object of 15 artists>)

# %%
plt.boxplot(data.mpg)
plt.show()

# %%
plt.boxplot(data.mpg,vert=False,notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f84c9a9f550>,
#   <matplotlib.lines.Line2D at 0x7f84c9a9f850>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f84c9a9d630>,
#   <matplotlib.lines.Line2D at 0x7f84c9a9df60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f84c9a9d6f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f84c9a9f790>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f84c9a9ff40>],
#  'means': []}

# %%
import numpy as np
mtcars = pd.read_csv("/content/mtcars.csv")

# %%
mtcars.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
mtcars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   0.000000   3.000000   2.0000
# 50%    17.710000   0.000000   0.000000   4.000000   2.0000
# 75%    18.900000   1.000000   1.000000   4.000000   4.0000
# max    22.900000   1.000000   1.000000   5.000000   8.0000

# %%
  mtcars.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
mtcars.hist(figsize=(15,5))
# Out:
# array([[<Axes: title={'center': 'mpg'}>, <Axes: title={'center': 'cyl'}>,
#         <Axes: title={'center': 'disp'}>],
#        [<Axes: title={'center': 'hp'}>, <Axes: title={'center': 'drat'}>,
#         <Axes: title={'center': 'wt'}>],
#        [<Axes: title={'center': 'qsec'}>, <Axes: title={'center': 'vs'}>,
#         <Axes: title={'center': 'am'}>],
#        [<Axes: title={'center': 'gear'}>,
#         <Axes: title={'center': 'carb'}>, <Axes: >]], dtype=object)

# %%
plt.figure(facecolor="purple")
plt.scatter(mtcars.mpg,mtcars.qsec,marker='*')

# %%
plt.violinplot(mtcars["mpg"])
plt.show()

# %%
plt.violinplot(mtcars["qsec"])
box=plt.boxplot(mtcars['qsec'])
plt.show()

# %%
import seaborn as sns

# %%
tips= sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.crosstab(tips['smoker'],tips['sex']).plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.stripplot(y='tip', data=tips,jitter=True)
# Out:
# <Axes: ylabel='tip'>

# %%
sns.stripplot(x='sex',y='tip',data=tips,jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.stripplot(x='day',y='tip', data=tips )
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day',y='tip', data=tips , size=5)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day', y='tip', data=tips,size=6)
# Out:
# <Axes: xlabel='day', ylabel='tip'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 9.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=tips , facecolor='green',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day',y='tip', data=tips, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
plt.subplot(2,2,1)
sns.boxplot(x='day', y='tip',data=tips)
plt.title=("Boxplot of tips")

plt.subplot(2,2,2)
sns.violinplot(x='day', y='tip', data=tips)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day',y='tip', data=tips, inner="stick", color="orange")
sns.stripplot(x='day', y='tip',data= tips,size=5,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
pd.plotting.scatter_matrix(tips)
# Out:
# array([[<Axes: xlabel='total_bill', ylabel='total_bill'>,
#         <Axes: xlabel='tip', ylabel='total_bill'>,
#         <Axes: xlabel='size', ylabel='total_bill'>],
#        [<Axes: xlabel='total_bill', ylabel='tip'>,
#         <Axes: xlabel='tip', ylabel='tip'>,
#         <Axes: xlabel='size', ylabel='tip'>],
#        [<Axes: xlabel='total_bill', ylabel='size'>,
#         <Axes: xlabel='tip', ylabel='size'>,
#         <Axes: xlabel='size', ylabel='size'>]], dtype=object)

# %%
sns.pairplot(tips)

# %%
data= pd.read_csv('train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.groupby('Survived')['PassengerId'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
pd.crosstab(data['Survived'],data['Sex']).plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
survived= data.loc[data['Survived']==1, "Age"].dropna()
sns.distplot(survived)
# Out:
# <ipython-input-113-23ef6be15255>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(survived)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
not_survived= data.loc[data['Survived']==1, "Age"].dropna()
sns.distplot(not_survived)
# Out:
# <ipython-input-117-b7fb2668b12a>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(not_survived)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(data)

# %%
grid= sns.FacetGrid(data, col='Survived',row='Pclass',height=2.4,aspect=1.5)
grid.map(plt.hist, 'Age', alpha=0.5,bins=20)
grid.add_legend()

# %%
figbi,axesbi = plt.subplots(2,4, figsize=(18,10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barh', ax=axesbi[0,0],xlim=[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barh', ax=axesbi[0,1],xlim=[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barh', ax=axesbi[0,2],xlim=[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barh', ax=axesbi[0,3],xlim=[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barh', ax=axesbi[1,0],xlim=[0,1])
sns.boxplot(x="Survived",y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived",y="Fare", data=data,ax=axesbi[1,2])
plt.show()
figbi.savefig("my1stfig.png")
from google.colab import files
files.download("my1stfig.png")
